# %% [markdown]
# # Barabasi Albert Model Experiments

# %%
from utils.basic_graphs_utilities import *
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("ggplot")

# %%
def draw_degree_distribution(graph, m, fig_title, file_title, theoretical_dist=False, loglog=True):
    degrees = [val for (node, val) in graph.degree()]
    degree_freq = nx.degree_histogram(graph)
    degrees = np.array(range(len(degree_freq)))
    plt.figure(figsize=(10, 8)) 
    if loglog:
        plt.loglog(degrees[m:], degree_freq[m:]/np.sum(degree_freq[m:]),'bo', mfc='none')
    else:
        plt.plot(degrees[m:], degree_freq[m:]/np.sum(degree_freq[m:]),'bo', mfc='none')
        plt.yscale('log')
    if theoretical_dist:
        plt.plot(degrees[m:], theoretical_dist(degrees[m:],m), 'r-', label="Theorical Distribution")
    plt.xlabel('k (degree)')
    plt.ylabel('P(k)')
    plt.title(fig_title)
    plt.legend()
    plt.savefig(f"results/50/barabasi_albert/{file_title}", dpi=300)
    plt.show()

# %%
nx_ba_graph = generate_graph(None, d=1,n=300000, tipology="barabasi_albert", mba=1 )
nx_ba_graph3 = generate_graph(None, d=1,n=300000, tipology="barabasi_albert", mba=3 )
nx_ba_graph5 = generate_graph(None, d=1,n=300000, tipology="barabasi_albert", mba=5 )
nx_ba_graph7 = generate_graph(None, d=1,n=300000, tipology="barabasi_albert", mba=7 )

# %%
def ba_powerlaw(x, m):
    return 2*(m**2)*1/(x**3)

draw_degree_distribution(
    nx_ba_graph, 
    1, 
    "Barabasi Albert Model - Nodes' Degree Distribution",
    "degree_distribution",
    ba_powerlaw,
    loglog=True
    )

# %%
m = 1

def ba_powerlaw2(x, m):
    return 2*(m**2)*1/(x**2.9)

degree_freq = nx.degree_histogram(nx_ba_graph)
degrees = np.array(range(len(degree_freq)))

degree_freq3 = nx.degree_histogram(nx_ba_graph3)
degrees3 = np.array(range(len(degree_freq3)))

degree_freq5 = nx.degree_histogram(nx_ba_graph5)
degrees5 = np.array(range(len(degree_freq5)))

degree_freq7 = nx.degree_histogram(nx_ba_graph7)
degrees7 = np.array(range(len(degree_freq7)))


plt.figure(figsize=(13, 11)) 

# plot different ms with different markers
plt.loglog(degrees[m:], degree_freq[m:]/np.sum(degree_freq[m:]),'ko', mfc='none', label="m = 1", alpha=0.8)
plt.loglog(degrees3[m:], degree_freq3[m:]/np.sum(degree_freq3[m:]),'ks', mfc='none', label="m = 3", alpha=0.8)
plt.loglog(degrees5[m:], degree_freq5[m:]/np.sum(degree_freq5[m:]),'kv', mfc='none', label="m = 5", alpha=0.8)
plt.loglog(degrees7[m:], degree_freq7[m:]/np.sum(degree_freq7[m:]),'kp', mfc='none', label="m = 7", alpha=0.8)

plt.plot(degrees[m:], ba_powerlaw2(degrees[m:],m), 'r-', label="Power Law, gamma = 2.9")
plt.xlabel('k (degree)', fontsize=15)
plt.ylabel('P(k)', fontsize=15)
plt.title("Degree Distribution, N = 300.000")
plt.legend(fontsize=15)
plt.tick_params(labelsize=13)
plt.savefig("results/50/barabasi_albert/degree_distribution_cfr", dpi=300)
plt.show()

# %%
# barabasi albert implementation from Bollobas et al (2001)
G, graph_list = generate_barabasi_albert(10000,1, save_steps=True)

# %%
# fig = plt.figure(figsize=(10,8))
# nx.draw_networkx(G, with_labels=True, font_weight='normal', node_size=100)

# %%
# save intermediate steps

# for i,g in enumerate(graph_list):
#     fig = plt.figure(figsize=(10,8))
#     # print(g.nodes)
#     nx.draw_kamada_kawai(g, with_labels=True, node_size=100)
#     plt.savefig(f"./frames/frame{i}")
#     plt.show()

# %% [markdown]
# ## Model A

# %%
n = 100000

GA, _ = ba_model_A(n,1)

# %%
# fig = plt.figure(figsize=(10,8))
# nx.draw_networkx(GA, node_size=100)

# %%
def exponential_modelA(x, m):
    return (np.e/m) * np.exp(-x/m)

draw_degree_distribution(
    GA, 
    1, 
    "Model A - Nodes' Degree Distribution",
    "degree_distribution_model_A",
    exponential_modelA,
    loglog=False
    )

# %% [markdown]
# ## Model B

# %%
GB, _ = ba_model_B(10000,10000)

# %%
draw_degree_distribution(
    GB,
    1,
    "Model B - Nodes' Degree Distribution",
    "degree_distribution_model_B",
    loglog=True
)
# Out:
# No handles with labels found to put in legend.
